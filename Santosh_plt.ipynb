# %% [markdown]
# <a href="https://colab.research.google.com/github/sbanty/QuarkMatter/blob/main/Santosh_plt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Pseudo scalar meson

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass  ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [139.6]  # Example mass values for pi+, pi- particles in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)





import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [139.6]  # Example mass values for pi+, pi- particles in MeV/c^2
particle_names = ['pi+', 'pi-']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = [
    [5.64700733599097e-16, 1.0929614812872462e-15, 1.8858532650330114e-15, 2.9870873845368844e-15, 4.455060122282685e-15, 6.343947335656176e-15, 8.693223123820672e-15],
    [5.64700733599097e-16, 1.0929614812872462e-15, 1.8858532650330114e-15, 2.9870873845368844e-15, 4.455060122282685e-15, 6.343947335656176e-15, 8.693223123820672e-15]
]  # Particle density values for pi+, pi-

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'{particle_names[i]}')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()




from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass  ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [135]  # Example mass values for pi0 particles in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)





import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [135]  # Example mass values for pi0 particles in MeV/c^2
particle_names = ['pi0']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = [
    [1.2440429272702768e-16, 2.4514591808588797e-16, 4.207187532055407e-16, 6.679303252509674e-16, 9.98121233311723e-16, 1.4245186177869154e-15, 1.9527631606905673e-15]
]  # Particle density values for pi0

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'{particle_names[i]}')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()






from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + (mass / 1000) ** 2)) / (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [493.7]  # Example mass values for K+, K- particles in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)



import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [493.7, 493.7]  # Example mass values for K+, K- particles in MeV/c^2
particle_names = ['K+', 'K-']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = [
    [4.767298155725092e-16, 9.311285447216787e-16, 1.6090053028065825e-15, 2.5550557658363008e-15, 3.8139755997912695e-15, 5.430460466064915e-15, 7.449206021474556e-15],  # Particle density values for K+
    [4.767298155725092e-16, 9.311285447216787e-16, 1.6090053028065825e-15, 2.5550557658363008e-15, 3.8139755997912695e-15, 5.430460466064915e-15, 7.449206021474556e-15]  # Particle density values for K-
]

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'{particle_names[i]}')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()







from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass **2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [497.6]  # Example mass values for k0, k'0 particles in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)






import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [497.6]  # Example mass values for k0, k'0 particles in MeV/c^2
particle_names = ['k0', "k'0"]
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'{particle_names[i]}')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()






from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp)))-z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [547.862, 957.78, 1769.57]  # Example mass values for eta particle in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_particle_density[i])
    print()

print("Partial pressure results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_partial_pressure[i])
    print()

print("Energy density results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_energy_density[i])
    print()

print("Entropy density results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_entropy_density[i])
    print()







import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [547.862, 957.78, 1769.57]  # Example mass values for eta particle in MeV/c^2
particle_names = ['eta']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'Mass {mass} MeV/c$^2$')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()





import matplotlib.pyplot as plt
from scipy.integrate import quad
import numpy as np

# Function to calculate particle density
def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

# Constants
mu = 0
g_values = [3, 3, 1, 2, 2, 1]  # Particle multiplicities for pi+, pi-, pi0, K+, K-, eta
mass_values_mev = [139.6, 139.6, 135, 493.7, 493.7, 547.8]  # Particle masses in MeV/c^2
particle_names = ['$\pi^+$', '$\pi^-$', '$\pi^0$', '$K^+$', '$K^-$', '$\eta$']
tmp_values_mev = np.linspace(80, 200, 100)  # Temperature values in MeV

results_particle_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

# Calculate particle density for each particle and temperature
for i, mass in enumerate(mass_values_mev):
    particle_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor
        particle_density_results.append(result_particle_density)
    results_particle_density.append(particle_density_results)

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

for i, particle_name in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.ylim(0, np.max(results_particle_density))

plt.show()
# Out:
# <ipython-input-6-12a38fbae577>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) - 1)
# <ipython-input-6-12a38fbae577>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-6-12a38fbae577>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass  ** 2) - mu) / tmp) - 1))
# Particle density results (fm^(-3)):
# [[2
RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)

# %% [markdown]
# Vector meson_plt

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + (mass / 1000) ** 2)) / (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [775]  # Example mass values for rho+,rho-,rho 0 particles in MeV/c^2
mu = 0
g = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)

import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [775]  # Example mass values for rho+, rho-, rho0 particles in MeV/c^2
particle_names = ['rho+', 'rho-', 'rho0']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

for i, particle in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[0], label=particle)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()



from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp)))-z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [891.66, 896.1, 892.0, 891.66]  # Mass values for K*+, K*0, K'*0, K'-* particles in MeV/c^2
mu = 0
g = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

particle_names = ['K*+', 'K*0', "K'*0", "K'-*"]
temperature_values = [f'{tmp} MeV' for tmp in tmp_values_mev]

print("Particle density results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_particle_density[i][j])
        print()

print("Partial pressure results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_partial_pressure[i][j])
        print()

print("Energy density results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_energy_density[i][j])
        print()

print("Entropy density results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_entropy_density[i][j])
        print()


import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [891.66, 896.1, 892.0, 891.66]  # Mass values for K*+, K*0, K'*0, K'-* particles in MeV/c^2
particle_names = ['K*+', 'K*0', "K'*0", "K'-*"]
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

for i, particle in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()


from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [782.65]  # Mass value for W0 particle in MeV/c^2
mu = 0
g = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)




import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "W0"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# Vector meson_plt1

# %%
import matplotlib.pyplot as plt
from scipy.integrate import quad
import numpy as np

# Particle density functions
def particle_density_rho_plus(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_rho_zero(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_rho_minus(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_kaon_plus(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_kaon_zero(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_kaon_star_zero(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_kaon_star_minus(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def particle_density_w0(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

# Constants and parameters
mass_values_mev = [775.26, 775.26, 775.26, 891.66, 891.66, 891.66, 891.66, 782.65]  # Mass values for rho+, rho0, rho-, K*+, K*0, K'*0, K'-*, and W0 particles in MeV/c^2
mu = 0
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

# Results array
results_particle_density_rho_plus = []
results_particle_density_rho_zero = []
results_particle_density_rho_minus = []
results_particle_density_kaon_plus = []
results_particle_density_kaon_zero = []
results_particle_density_kaon_star_zero = []
results_particle_density_kaon_star_minus = []
results_particle_density_w0 = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

# Calculate particle density for each temperature and particle
for mass in mass_values_mev:
    particle_density_results_rho_plus = []
    particle_density_results_rho_zero = []
    particle_density_results_rho_minus = []
    particle_density_results_kaon_plus = []
    particle_density_results_kaon_zero = []
    particle_density_results_kaon_star_zero = []
    particle_density_results_kaon_star_minus = []
    particle_density_results_w0 = []
    for tmp in tmp_values_mev:
        result_particle_density_rho_plus = quad(particle_density_rho_plus, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_rho_zero = quad(particle_density_rho_zero, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_rho_minus = quad(particle_density_rho_minus, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_kaon_plus = quad(particle_density_kaon_plus, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_kaon_zero = quad(particle_density_kaon_zero, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_kaon_star_zero = quad(particle_density_kaon_star_zero, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_kaon_star_minus = quad(particle_density_kaon_star_minus, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        result_particle_density_w0 = quad(particle_density_w0, 0, np.inf, args=(3, mass, mu, tmp))[0] * conversion_factor
        particle_density_results_rho_plus.append(result_particle_density_rho_plus)
        particle_density_results_rho_zero.append(result_particle_density_rho_zero)
        particle_density_results_rho_minus.append(result_particle_density_rho_minus)
        particle_density_results_kaon_plus.append(result_particle_density_kaon_plus)
        particle_density_results_kaon_zero.append(result_particle_density_kaon_zero)
        particle_density_results_kaon_star_zero.append(result_particle_density_kaon_star_zero)
        particle_density_results_kaon_star_minus.append(result_particle_density_kaon_star_minus)
        particle_density_results_w0.append(result_particle_density_w0)
    results_particle_density_rho_plus.append(particle_density_results_rho_plus)
    results_particle_density_rho_zero.append(particle_density_results_rho_zero)
    results_particle_density_rho_minus.append(particle_density_results_rho_minus)
    results_particle_density_kaon_plus.append(particle_density_results_kaon_plus)
    results_particle_density_kaon_zero.append(particle_density_results_kaon_zero)
    results_particle_density_kaon_star_zero.append(particle_density_results_kaon_star_zero)
    results_particle_density_kaon_star_minus.append(particle_density_results_kaon_star_minus)
    results_particle_density_w0.append(particle_density_results_w0)

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

plt.plot(tmp_values_mev, results_particle_density_rho_plus[0], label='rho+')
plt.plot(tmp_values_mev, results_particle_density_rho_zero[0], label='rho0')
plt.plot(tmp_values_mev, results_particle_density_rho_minus[0], label='rho-')
plt.plot(tmp_values_mev, results_particle_density_kaon_plus[0], label='K*+')
plt.plot(tmp_values_mev, results_particle_density_kaon_zero[0], label='K*0')
plt.plot(tmp_values_mev, results_particle_density_kaon_star_zero[0], label="K'*0")
plt.plot(tmp_values_mev, results_particle_density_kaon_star_minus[0], label="K'-*")
plt.plot(tmp_values_mev, results_particle_density_w0[0], label='W0')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-7-d6d6d2c70973>:7: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-d6d6d2c70973>:12: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-d6d6d2c70973>:17: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-d6d6d2c70973>:22: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-d6d6d2c70973>:27: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-d6d6d2c70973>:32: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-d6d6d2c70973>:37: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-7-d6d6d2c70973>:42: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)

# %% [markdown]
# Baryon

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = (g / (2 * np.pi ** 2)) * y
    return entropy_density

mass_values_mev = [938.272]  # Mass value for proton particle in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)


import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "Proton"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()






from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = (g / (2 * np.pi ** 2)) * y
    return entropy_density

mass_values_mev = [939.565]  # Mass value for neutron particle in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)


import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "Neutron"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()


from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [1115.683]  # Mass value for lambda particle in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)

import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "Lambda"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()




from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

particle_names = ["Sigma+", "Sigma0", "Sigma-"]
mass_values_mev = [1189.37, 1192.64, 1197.45]  # Mass values for sigma+ , sigma0 , sigma- particles in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for i, mass in enumerate(mass_values_mev):
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_particle_density[i])

print("\nPartial pressure results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_partial_pressure[i])

print("\nEnergy density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_energy_density[i])

print("\nEntropy density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_entropy_density[i])

import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

for i, particle_name in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()



from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

particle_names = ["Xi0", "Xi-"]
mass_values_mev = [1314.86, 1321.71]  # Mass values for Xi0  and Xi- particles in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.97e-7) ** 3  # Conversion factor from MeV^3 to fm^(-3)

for i, mass in enumerate(mass_values_mev):
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_particle_density[i])

print("\nPartial pressure results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_partial_pressure[i])

print("\nEnergy density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_energy_density[i])

print("\nEntropy density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_entropy_density[i])
import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

for i, particle_name in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-8-9c428a7cd26e>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-8-9c428a7cd26e>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-8-9c428a7cd26e>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# Particle density results (fm^(-3)):
# [[1.8761900723926373e-19, 2.838814098924525e-18, 1.8470468897157256e-17, 7.362875477587615e-17, 2.1503379214124282e-16, 5.086752407634584e-16, 1.035787254720211e-15]]
#
# Partial pressure results (fm^(-3)):
# [[1.5009540427075288e-17, 2.8388526097311947e-16, 2.216597494781403e-15, 1.0309999658654867e-14, 3.4420386930889436e-14, 9.163679515282326e-14, 2.0743957317380718e-13]]
#
# Energy density results (fm^(-3)):
# [[2.0075746682803447e-16, 3.1404845736736397e-15, 2.1124124620120583e-14, 8.704254952940529e-14, 2.6271855972648874e-13, 6.421275249169027e-13, 1.3506060773816771e-12]]
#
# Entropy density results (fm^(-3)):
# [[2.6970875908020803e-18, 3.4243698346467586e-17, 1.945060176241832e-16, 6.95375351343287e-16, 1.8571184166086136e-15, 4.07646844483181e-15, 7.790228252777424e-15]]
# <ipython-input-8-9c428a7cd26e>:90: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-8-9c428a7cd26e>:100: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-8-9c428a7cd26e>:105: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# Particle density results (fm^(-3)):
# [