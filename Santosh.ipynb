# %% [markdown]
# <a href="https://colab.research.google.com/github/sbanty/QuarkMatter/blob/main/Santosh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Working code

# %%
from scipy.integrate import quad
import numpy as np


def number(x,g,mass,mu,n,tmp):
  y= x**n/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)
  z=(g/(2.0*np.pi**2))*y
  return z

mass =1
n=2
tmp=1.0
mu=0
g=2
result= quad(number, 0, np.inf, args=(g,mass,mu,n,tmp))[0]
print(result)
# Out:
# 0.15349686594585502
# <ipython-input-3-a759418c5bba>:6: RuntimeWarning: overflow encountered in exp
#   y= x**n/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)

# %%
from scipy.integrate import quad
import numpy as np


def number(x,g,mass,mu,n,tmp):
  y= x**n*(np.log(np.exp(-(np.sqrt(x**2+mass**2)-mu)/tmp)+1))
  z=(g/(2.0*np.pi**2))*y
  return z

mass =1
n=2
tmp=1.0
mu=0
g=2
result= quad(number, 0, np.inf, args=(g,mass,mu,n,tmp))[0]
print(result)
# Out:
# 0.1588027433623237

# %%
from scipy.integrate import quad
import numpy as np


def number(x,g,mass,mu,n,tmp):
  y= x**n/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)
  z=(g/(2.0*np.pi**2))*y
  return z

mass =1
n=2
tmp=1.0
mu=0
g=2
result= quad(number, 0, np.inf, args=(g,mass,mu,n,tmp))[0]
print(result)
# Out:
# 0.15349686594585502
# <ipython-input-1-a759418c5bba>:6: RuntimeWarning: overflow encountered in exp
#   y= x**n/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)

# %%
from scipy.integrate import quad
import numpy as npnp


def number(x,g,mass,mu,n,tmp):
  y= x**n*(np.sqrt(x**2+mass**2))/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)
  z=(g/(2.0*np.pi**2))*y
  return z

mass =1
n=2
tmp=1.0
mu=0
g=2
result= quad(number, 0, np.inf, args=(g,mass,mu,n,tmp))[0]
print(result)
# Out:
# 0.531412849439106
# <ipython-input-7-f552c5840858>:6: RuntimeWarning: overflow encountered in exp
#   y= x**n*(np.sqrt(x**2+mass**2))/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)

# %%
from scipy.integrate import quad
import numpy as np


def number(x,g,mass,mu,n,tmp):
  y= x**n/(np.log((np.exp(-(np.sqrt(x**2+mass**2)-mu)/tmp)+1)))
  z=(g/(2.0*np.pi**2))*y
  return z

mass =1
n=2
tmp=1.0
mu=0
g=2
result= quad(number, 0, np.inf, args=(g,mass,mu,n,tmp))[0]
print(result)
# Out:
# nan
# <ipython-input-10-dbc99f62a7da>:6: RuntimeWarning: divide by zero encountered in double_scalars
#   y= x**n/(np.log((np.exp(-(np.sqrt(x**2+mass**2)-mu)/tmp)+1)))
# <ipython-input-10-dbc99f62a7da>:15: IntegrationWarning: The occurrence of roundoff error is detected, which prevents
#   the requested tolerance from being achieved.  The error may be
#   underestimated.
#   result= quad(number, 0, np.inf, args=(g,mass,mu,n,tmp))[0]

# %% [markdown]
# pressure

# %%
from scipy.integrate import quad
import numpy as np


def numbers(x,g,mass,mu,tmp):
  y= x**2/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)
  numb=(g/(2.0*np.pi**2))*y
  return numb


def pressure(x,g,mass,mu,tmp):
  press  = tmp*(g/(2.0*np.pi**2))*x**2*np.log(np.exp(-(np.sqrt(x**2+mass**2)-mu)/tmp)+1)
  return press


mass =1
n=2
tmp=0.5
mu=0
g=2
result = quad(pressure, 0, np.inf, args=(g,mass,mu,tmp))[0]
print(result)
result1 = quad(numbers, 0, np.inf, args=(g,mass,mu,tmp))[0]
print(result1)
# Out:
# 0.006322102612590224
# 0.012441259301052108
# <ipython-input-15-ea4e85ad34b0>:6: RuntimeWarning: overflow encountered in exp
#   y= x**2/(np.exp((np.sqrt(x**2+mass**2)-mu)/tmp)+1)

# %% [markdown]
#  for Meson

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass  ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density
g=[g1,g2]
mass_values_mev = [139.6,135,493.7,497.6,547.862]  #  mass values for pi+-,Pi0,k+-,K0 k'0, eta particles in MeV/c^2
mu = 0
g1 = 1

tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  #  temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g1, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g1, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g1, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g1, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)


mass_values_mev = [775.26, 775.26, 775.26, 891.76, 896.10, 896.10, 896.10, 782.65]  # mass values for rho, k*, w0 eta particles in MeV/c^2
mu = 0
g2 = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  #  temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g2, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g2, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g2, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g2, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)




import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

#mass_values_mev = [139.6,135,493.7,497.6,547.862]  # mass values for pi+-,Pi0,k+-,K0 k'0, eta particles in MeV/c^2
particle_names = ['pi+', 'pi-', 'pi0', 'K+', 'K-', 'K0','eta']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

numberdensitypion=[0.0039472299881886585, 0.009297094489335479, 0.018033980250364155, 0.030935811301194174, 0.04876665357383571, 0.072281907579621, 0.10223125366473636]

numberdensityneutralpion=[0.0040750934157599665, 0.009518069857222923, 0.0183657850057352, 0.03139308009412946, 0.04936179493925689, 0.07302566943468124, 0.10313310592161555]

numberdensitykaon=[0.0001724151141698021, 0.0008836458723164689, 0.0028196629785569595, 0.006810237470296332, 0.013751054384876928, 0.02455318344199813, 0.040120181287363985]

numberdensityneutralkaon=[0.00016581827503588258, 0.0008577630444783472, 0.0027536734462272065, 0.006678918746405322, 0.013527451269732434, 0.02421030989718341, 0.03963193979968982]

numberdenistyneutaleta=[9.976928097951086e-05, 0.000582027319385251, 0.002020983203023639, 0.005177563272534232, 0.010915081667485376, 0.020137588043756947, 0.03375642192309524]

numberdensitypseudoscalarmeson = []
for i in range(7):
    numberdensitypseudoscalarmeson.append(numberdensitypion[i] + numberdensityneutralpion[i] + numberdensitykaon[i] + numberdensityneutralkaon[i] + numberdenistyneutaleta[i])


mass_values_mev = [775.26, 775.26, 775.26, 891.76, 896.10, 896.10, 896.10, 782.65]  # mass values for rho, k*, w0 eta particles in MeV/c^2
particle_names = ['rho+', 'rho-', 'rho0', 'K*+', 'K*0', 'K*-','Kbar*0', 'w0']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV
particledensityrhoplus = [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013]
particledensityrhominus = [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013]
particledensityrhonot = [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013]
particledensitykstarplus = [7.683896787560611e-06, 0.00010368418337358757, 0.0006254676892257744, 0.0023641198938024375, 0.006640970586599348, 0.015258735857391053, 0.030392569249726192]
particledensitykstarzero = [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728]
particledensitykstarminus = [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728]
particledensitykstarbar = [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728]
particledensitywnot = [2.524375841685121e-05, 0.00026055667468660883, 0.0013166069375934535, 0.004390596104440139, 0.011240129027882389, 0.024050173122209185, 0.04528643654883241]
numberdensitymeson = []
for i in range(7):
    numberdensitymeson.append(particledensityrhoplus[i] + particledensityrhominus[i] + particledensityrhonot[i] + particledensitykstarplus[i] + particledensitykstarzero[i] + particledensitykstarminus[i] + particledensitykstarbar[i] + particledensitywnot[i])

print("Number density of mesons:")
print(numberdensitymeson)


numberdensity=[]
for i in range(7):
  numberdensity.append(numberdensitypseudoscalarmeson[i]+numberdensitymeson[i])





plt.plot(tmp_values_mev, numberdensitypion, label=r'$\pi^+$')
plt.plot(tmp_values_mev, numberdensitypion, label=r'$\pi^-$')
plt.plot(tmp_values_mev, numberdensitypion, label=r'$\pi^0$')
plt.plot(tmp_values_mev, numberdensitykaon, label=r'$K^+$')
plt.plot(tmp_values_mev, numberdensitykaon, label=r'$K^-$')
plt.plot(tmp_values_mev, numberdensitykaon, label=r'$K^0$')
plt.plot(tmp_values_mev, numberdensitypion, label=r'$\eta^0$')
plt.plot(tmp_values_mev, particledensityrhoplus, label=r'$\rho^+$')
plt.plot(tmp_values_mev, particledensityrhominus, label=r'$\rho^-$')
plt.plot(tmp_values_mev, particledensityrhonot, label=r'$\rho^0$')
plt.plot(tmp_values_mev, particledensitykstarplus, label=r'$K^*+$')
plt.plot(tmp_values_mev, particledensitykstarzero, label=r'$K^*0$')
plt.plot(tmp_values_mev, particledensitykstarminus, label=r'$K^-$')
plt.plot(tmp_values_mev, particledensitykstarbar, label=r'$\bar{K}^*0$')
plt.plot(tmp_values_mev, particledensitywnot, label=r'$w^0$')
plt.plot(tmp_values_mev, numberdensitypseudoscalarmeson, label='Total')
plt.plot(tmp_values_mev, numberdensitymeson, label='Total')
plt.plot(tmp_values_mev, numberdensity, label='Total')
plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-11-e5c28e40684f>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) - 1)
# <ipython-input-11-e5c28e40684f>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-11-e5c28e40684f>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass  ** 2) - mu) / tmp) - 1))
# Particle density results (fm^(-3)):
# [[2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013], [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013], [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013], [7.683896787560611e-06, 0.00010368418337358757, 0.0006254676892257744, 0.0023641198938024375, 0.006640970586599348, 0.015258735857391053, 0.030392569249726192], [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728], [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728], [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728], [2.524375841685121e-05, 0.00026055667468660883, 0.0013166069375934535, 0.004390596104440139, 0.011240129027882389, 0.024050173122209185, 0.04528643654883241]]
#
# Partial pressure results (fm^(-3)):
# [[0.002187233156030425, 0.02771183730048664, 0.16600966376701032, 0.6402175781905732, 1.8603905639086222, 4.453212266869855, 9.272503709860723], [0.002187233156030425, 0.02771183730048664, 0.16600966376701032, 0.6402175781905732, 1.8603905639086222, 4.453212266869855, 9.272503709860723], [0.002187233156030425, 0.02771183730048664, 0.16600966376701032, 0.6402175781905732, 1.8603905639086222, 4.453212266869855, 9.272503709860723], [0.0006147102945626201, 0.010368195352345238, 0.07504910959045351, 0.3308888383245861, 1.0619389725351913, 2.7436559449346474, 6.068063486960935], [0.0005860691166052046, 0.009991276443973816, 0.07283406391310064, 0.32273549182608263, 1.0396341512761118, 2.6937340450553506, 5.971167846515951], [0.0005860691166052046, 0.009991276443973816, 0.07283406391310064, 0.32273549182608263, 1.0396341512761118, 2.6937340450553506, 5.971167846515951], [0.0005860691166052046, 0.009991276443973816, 0.07283406391310064, 0.32273549182608263, 1.0396341512761118, 2.6937340450553506, 5.971167846515951], [0.0020194822507896004, 0.02605401911848336, 0.1579566889396904, 0.6143327477330481, 1.7963907460854058, 4.320744355117509, 9.030878428814857]]
#
# Energy density results (fm^(-3)):
# [[0.024859254728007818, 0.2623270293424517, 1.36320890077927, 4.689644823433676, 12.405445046727085, 27.44951070343703, 53.46706835310249], [0.024859254728007818, 0.2623270293424517, 1.36320890077927, 4.689644823433676, 12.405445046727085, 27.44951070343703, 53.46706835310249], [0.024859254728007818, 0.2623270293424517, 1.36320890077927, 4.689644823433676, 12.405445046727085, 27.44951070343703, 53.46706835310249], [0.00786888323441814, 0.1099659461368756, 0.6869379314848809, 2.6881379462438635, 7.815222315463116, 18.57706206499324, 38.26181533605228], [0.007533643094774702, 0.10639372961560814, 0.6692277947313251, 2.6315546111222425, 7.678014604349923, 18.300424001568288, 37.771882707820644], [0.007533643094774702, 0.10639372961560814, 0.6692277947313251, 2.6315546111222425, 7.678014604349923, 18.300424001568288, 37.771882707820644], [0.007533643094774702, 0.10639372961560814, 0.6692277947313251, 2.6315546111222425, 7.678014604349923, 18.300424001568288, 37.771882707820644], [0.023136193094391976, 0.24851223592014177, 1.3064777754919366, 4.531007039185682, 12.056931063636888, 26.798032237698774, 52.379934391997026]]
#
# Entropy density results (fm^(-3)):
# [[0.00033808109855047806, 0.0029003886664293833, 0.012743488037885668, 0.0380704457258875, 0.08916147256647318, 0.17723734983503828, 0.3136978603148161], [0.00033808109855047806, 0.0029003886664293833, 0.012743488037885668, 0.0380704457258875, 0.08916147256647318, 0.17723734983503828, 0.3136978603148161], [0.00033808109855047806, 0.0029003886664293833, 0.012743488037885668, 0.0380704457258875, 0.08916147256647318, 0.17723734983503828, 0.3136978603148161], [0.00010604491911225949, 0.0012033414148922084, 0.006349892008961121, 0.021564477032610024, 0.05548225804998942, 0.11844843338848828, 0.22164939411506607], [0.00010149640264224884, 0.0011638500605958195, 0.006183848822036881, 0.021102072163885717, 0.05448530472266272, 0.1166342113701313, 0.21871525277168305], [0.00010149640264224884, 0.0011638500605958195, 0.006183848822036881, 0.021102072163885717, 0.05448530472266272, 0.1166342113701313, 0.21871525277168305], [0.00010149640264224884, 0.0011638500605958195, 0.006183848822036881, 0.021102072163885717, 0.05448530472266272, 0.1166342113701313, 0.21871525277168305], [0.00031444594181476973, 0.002745662550386251, 0.012203620536930228, 0.0367524270494195, 0.08658326131076434, 0.17288209218231265, 0.3070540641040594]]
# Number density of mesons:
# [0.00013692735949194718, 0.001495397024399834, 0.007914340937496775, 0.02739945473518897, 0.07230881192364741, 0.158619435386216, 0.30490666147975437]

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass  ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [775.26, 775.26, 775.26, 891.76, 896.10, 896.10, 896.10, 782.65]  # mass values for rho, k*, w0 eta particles in MeV/c^2
mu = 0
g = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  #  temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)




import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [775.26, 775.26, 775.26, 891.76, 896.10, 896.10, 896.10, 782.65]  # mass values for rho, k*, w0 eta particles in MeV/c^2
particle_names = ['rho+', 'rho-', 'rho0', 'K*+', 'K*0', 'K*-','Kbar*0', 'w0']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV
particledensityrhoplus = [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013]
particledensityrhominus = [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013]
particledensityrhonot = [2.734068778216081e-05, 0.0002771372326043581, 0.001383750174468794, 0.004575731737671318, 0.01164118504765826, 0.024789448124486982, 0.0465030354779013]
particledensitykstarplus = [7.683896787560611e-06, 0.00010368418337358757, 0.0006254676892257744, 0.0023641198938024375, 0.006640970586599348, 0.015258735857391053, 0.030392569249726192]
particledensitykstarzero = [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728]
particledensitykstarminus = [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249728]
particledensitykstarbar = [7.325880313684304e-06, 9.991482284218788e-05, 0.0006070052624237216, 0.0023058478413108133, 0.006501385722063629, 0.014980727344384943, 0.02990618308249
# [[1.6844043599559448, 4.112322472509987, 8.527319922233685, 15.797921896423201, 26.950567252792005, 43.16960851947093, 65.79731189500824], [1.6844043599559448, 4.112322472509987, 8.527319922233685, 15.797921896423201, 26.950567252792005, 43.16960851947093, 65.79731189500824]]
#
# Entropy density results (fm^(-3)):
# [[0.0280733386898355, 0.054830882064858144, 0.09474789797464594, 0.15045628092616437, 0.22458792542636827, 0.3197747259822319, 0.43864857710072525], [0.0280733386898355, 0.054830882064858144, 0.09474789797464594, 0.15045628092616437, 0.22458792542636827, 0.3197747259822319, 0.43864857710072525]]

# %% [markdown]
#  for k0,k0'

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass **2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [497.6]  # Example mass values for k0, k'0 particles in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)






import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [497.6, 497.6]  # Mass values for k0 and k'0 particles in MeV/c^2
particle_names = ['k0', "k'0"]
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = [
    [0.00016581827503588258, 0.0008577630444783472, 0.0027536734462272065, 0.006678918746405322, 0.013527451269732434, 0.02421030989718341, 0.03963193979968982],  # Particle density values for k0
    [0.00016581827503588258, 0.0008577630444783472, 0.0027536734462272065, 0.006678918746405322, 0.013527451269732434, 0.02421030989718341, 0.03963193979968982]  # Particle density values for k'0
]

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'{particle_names[i]}')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-7-c1163990a849>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass **2) - mu) / tmp) - 1)
# <ipython-input-7-c1163990a849>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-7-c1163990a849>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + (mass / 1000) ** 2) - mu) / tmp) - 1))
# Particle density results (fm^(-3)):
# [[0.00016581827503588258, 0.0008577630444783472, 0.0027536734462272065, 0.006678918746405322, 0.013527451269732434, 0.02421030989718341, 0.03963193979968982]]
#
# Partial pressure results (fm^(-3)):
# [[0.013261378833770585, 0.08568713360344082, 0.32967198541972065, 0.9311949864744575, 2.1507293166775447, 4.3195918482215765, 7.835867646647467]]
#
# Energy density results (fm^(-3)):
# [[0.10582128227481614, 0.581943786776071, 1.9830582857709282, 5.0963030077253935, 10.915565954397255, 20.6179956833212, 35.55068491602263]]
#
# Entropy density results (fm^(-3)):
# [[0.02122082012407038, 0.04198009404760699, 0.07380826348085641, 0.1194936892017263, 0.18188310033749366, 0.2638288873072151, 0.36816589368115027]]

# %% [markdown]
# For Eta0

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp)))-z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [547.862, 957.78, 1769.57]  # Example mass values for eta particle in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV


results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_particle_density[i])
    print()

print("Partial pressure results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_partial_pressure[i])
    print()

print("Energy density results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_energy_density[i])
    print()

print("Entropy density results (fm^(-3)):")
for i, mass in enumerate(mass_values_mev):
    print(f"Mass {mass} MeV/c^2:")
    print(results_entropy_density[i])
    print()







import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [547.862, 957.78, 1769.57]  # Example mass values for eta particle in MeV/c^2
particle_names = ['eta']
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = [
    [9.976928097951086e-05, 0.000582027319385251, 0.002020983203023639, 0.005177563272534232, 0.010915081667485376, 0.020137588043756947, 0.03375642192309524]
,  # Particle density values for eta0
    [1.2358397069022677e-06, 1.96213982231546e-05, 0.00013182323036227688, 0.0005377587946221883, 0.0015986602028755183, 0.0038368071861970693, 0.007909997143620688],
  # Particle density values for eta0
    [1.136689331566434e-10, 1.3522048317585512e-08, 3.4619791487466853e-07, 3.6576352551063187e-06, 2.21221319788707e-05, 9.196499224616185e-05, 0.0002934294124917463]
     # Particle density values for eta0
]

for i, mass in enumerate(mass_values_mev):
    plt.plot(tmp_values_mev, results_particle_density[i], label=f'Mass {mass} MeV/c$^2$')

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-13-d94d030fa04f>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-13-d94d030fa04f>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input
.741750128818543e-05, 0.0002777389141238456, 0.0013861714866835054, 0.00458237844930305, 0.011655536155271099, 0.024815834601684645, 0.04654637159425796], [2.741750128818543e-05, 0.0002777389141238456, 0.0013861714866835054, 0.00458237844930305, 0.011655536155271099, 0.024815834601684645, 0.04654637159425796]]
#
# Partial pressure results (fm^(-3)):
# [[0.002193378104177419, 0.027771996499823082, 0.166300064438606, 0.6411468579838925, 1.86268054387858, 4.457939904083557, 9.281109417016859], [0.002193378104177419, 0.027771996499823082, 0.166300064438606, 0.6411468579838925, 1.86268054387858, 4.457939904083557, 9.281109417016859], [0.002193378104177419, 0.027771996499823082, 0.166300064438606, 0.6411468579838925, 1.86268054387858, 4.457939904083557, 9.281109417016859]]
#
# Energy density results (fm^(-3)):
# [[0.02492208377317542, 0.26282607759625937, 1.3652456020196662, 4.695315154728032, 12.417861945571197, 27.472664122816997, 53.50562965724462], [0.02492208377317542, 0.26282607759625937, 1.3652456020196662, 4.695315154728032, 12.417861945571197, 27.472664122816997, 53.50562965724462], [0.02492208377317542, 0.26282607759625937, 1.3652456020196662, 4.695315154728032, 12.417861945571197, 27.472664122816997, 53.50562965724462]]
#
# Entropy density results (fm^(-3)):
# [[0.0003389432734669105, 0.0029059807409608247, 0.012762880553818934, 0.03811758580508518, 0.0892533905590611, 0.17739224459389194, 0.31393369537130744], [0.0003389432734669105, 0.0029059807409608247, 0.012762880553818934, 0.03811758580508518, 0.0892533905590611, 0.17739224459389194, 0.31393369537130744], [0.0003389432734669105, 0.0029059807409608247, 0.012762880553818934, 0.03811758580508518, 0.0892533905590611, 0.17739224459389194, 0.31393369537130744]]

# %% [markdown]
# for k*

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp)))-z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [891.66, 896.1, 892.0, 891.66]  # Mass values for K*+, K*0, K'*0, K'-* particles in MeV/c^2
mu = 0
g = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

particle_names = ['K*+', 'K*0', "K'*0", "K'-*"]
temperature_values = [f'{tmp} MeV' for tmp in tmp_values_mev]

print("Particle density results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_particle_density[i][j])
        print()

print("Partial pressure results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_partial_pressure[i][j])
        print()

print("Energy density results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_energy_density[i][j])
        print()

print("Entropy density results (fm^(-3)):")
for i, particle in enumerate(particle_names):
    print(f"{particle} particle:")
    for j, temperature in enumerate(temperature_values):
        print(f"Temperature: {temperature}")
        print(results_entropy_density[i][j])
        print()


import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [891.66, 896.1, 892.0, 891.66]  # Mass values for K*+, K*0, K'*0, K'-* particles in MeV/c^2
particle_names = ["K*+", "K*0", "K'*0", "K'-*"]
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

for i, particle in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-30-b852b39865fb>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-30-b852b39865fb>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-30-b852b39865fb>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
# Particle density results (fm^(-3)):
# K*+ particle:
# Temperature: 80 MeV
# 7.692346444725238e-06
#
# Temperature: 100 MeV
# 0.0001037726578565678
#
# Temperature: 120 MeV
# 0.0006258994571529465
#
# Temperature: 140 MeV
# 0.0023654791171395092
#
# Temperature: 160 MeV
# 0.006644220152364749
#
# Temperature: 180 MeV
# 0.015265198262734668
#
# Temperature: 200 MeV
# 0.030403862049397757
#
# K*0 particle:
# Temperature: 80 MeV
# 7.325880313684304e-06
#
# Temperature: 100 MeV
# 9.991482284218788e-05
#
# Temperature: 120 MeV
# 0.0006070052624237216
#
# Temperature: 140 MeV
# 0.0023058478413108133
#
# Temperature: 160 MeV
# 0.006501385722063629
#
# Temperature: 180 MeV
# 0.014980727344384943
#
# Temperature: 200 MeV
# 0.02990618308249728
#
# K'*0 particle:
# Temperature: 80 MeV
# 7.663654985842443e-06
#
# Temperature: 100 MeV
# 0.0001034721461994909
#
# Temperature: 120 MeV
# 0.0006244326265664902
#
# Temperature: 140 MeV
# 0.0023608608210230427
#
# Temperature: 160 MeV
# 0.006633177789297708
#
# Temperature: 180 MeV
# 0.015243236552222714
#
# Temperature: 200 MeV
# 0.0303654823535995
#
# K'-* particle:
# Temperature: 80 MeV
# 7.692346444725238e-06
#
# Temperature: 100 MeV
# 0.0001037726578565678
#
# Temperature: 120 MeV
# 0.0006258994571529465
#
# Temperature: 140 MeV
# 0.0023654791171395092
#
# Temperature: 160 MeV
# 0.006644220152364749
#
# Temperature: 180 MeV
# 0.015265198262734668
#
# Temperature: 200 MeV
# 0.030403862049397757
#
# Partial pressure results (fm^(-3)):
# K*+ particle:
# Temperature: 80 MeV
# 0.0006153862636757655
#
# Temperature: 100 MeV
# 0.010377042389381098
#
# Temperature: 120 MeV
# 0.07510091112912323
#
# Temperature: 140 MeV
# 0.33107901725893346
#
# Temperature: 160 MeV
# 1.0624582243166967
#
# Temperature: 180 MeV
# 2.7448163627546167
#
# Temperature: 200 MeV
# 6.070313088925636
#
# K*0 particle:
# Temperature: 80 MeV
# 0.0005860691166052046
#
# Temperature: 100 MeV
# 0.009991276443973816
#
# Temperature: 120 MeV
# 0.07283406391310064
#
# Temperature: 140 MeV
# 0.32273549182608263
#
# Temperature: 160 MeV
# 1.0396341512761118
#
# Temperature: 180 MeV
# 2.6937340450553506
#
# Temperature: 200 MeV
# 5.971167846515951
#
# K'*0 particle:
# Temperature: 80 MeV
# 0.0006130909583884537
#
# Temperature: 100 MeV
# 0.010346992619208897
#
# Temperature: 120 MeV
# 0.07492492747509975
#
# Temperature: 140 MeV
# 0.33043283715617683
#
# Temperature: 160 MeV
# 1.0606937509404526
#
# Temperature: 180 MeV
# 2.7408728154189808
#
# Temperature: 200 MeV
# 6.062667576099392
#
# K'-* particle:
# Temperature: 80 MeV
# 0.0006153862636757655
#
# Temperature: 100 MeV
# 0.010377042389381098
#
# Temperature: 120 MeV
# 0.07510091112912323
#
# Temperature: 140 MeV
# 0.33107901725893346
#
# Temperature: 160 MeV
# 1.0624582243166967
#
# Temperature: 180 MeV
# 2.7448163627546167
#
# Temperature: 200 MeV
# 6.070313088925636
#
# Energy density results (fm^(-3)):
# K*+ particle:
# Temperature: 80 MeV
# 0.007876776773361856
#
# Temperature: 100 MeV
# 0.11004959874424872
#
# Temperature: 120 MeV
# 0.6873511571141058
#
# Temperature: 140 MeV
# 2.6894547937462603
#
# Temperature: 160 MeV
# 7.818409408137126
#
# Temperature: 180 MeV
# 18.583478441061416
#
# Temperature: 200 MeV
# 38.27316572907996
#
# K*0 particle:
# Temperature: 80 MeV
# 0.007533643094774702
#
# Temperature: 100 MeV
# 0.10639372961560814
#
# Temperature: 120 MeV
# 0.6692277947313251
#
# Temperature: 140 MeV
# 2.6315546111222425
#
# Temperature: 160 MeV
# 7.678014604349923
#
# Temperature: 180 MeV
# 18.300424001568288
#
# Temperature: 200 MeV
# 37.771882707820644
#
# K'*0 particle:
# Temperature: 80 MeV
# 0.007849970225094297
#
# Temperature: 100 MeV
# 0.10976542912613782
#
# Temperature: 120 MeV
# 0.6859471446349331
#
# Temperature: 140 MeV
# 2.68497992968779
#
# Temperature: 160 MeV
# 7.80757802119586
#
# Temperature: 180 MeV
# 18.561670545528965
#
# Temperature: 200 MeV
# 38.23458574039278
#
# K'-* particle:
# Temperature: 80 MeV
# 0.007876776773361856
#
# Temperature: 100 MeV
# 0.11004959874424872
#
# Temperature: 120 MeV
# 0.6873511571141058
#
# Temperature: 140 MeV
# 2.6894547937462603
#
# Temperature: 160 MeV
# 7.818409408137126
#
# Temperature: 180 MeV
# 18.583478441061416
#
# Temperature: 200 MeV
# 38.27316572907996
#
# Entropy density results (fm^(-3)):
# K*+ particle:
# Temperature: 80 MeV
# 0.00010615203796297027
#
# Temperature: 100 MeV
# 0.0012042664113362982
#
# Temperature: 120 MeV
# 0.0063537672353602415
#
# Temperature: 140 MeV
# 0.021575241507157464
#
# Temperature: 160 MeV
# 0.055505422702836385
#
# Temperature: 180 MeV
# 0.11849052668786686
#
# Temperature: 200 MeV
# 0.22171739409002794
#
# K*0 particle:
# Temperature: 80 MeV
# 0.00010149640264224884
#
# Temperature: 100 MeV
# 0.0011638500605958195
#
# Temperature: 120 MeV
# 0.006183848822036881
#
# Temperature: 140 MeV
# 0.021102072163885717
#
# Temperature: 160 MeV
# 0.05448530472266272
#
# Temperature: 180 MeV
# 0.1166342113701313
#
# Temperature: 200 MeV
# 0.21871525277168305
#
# K'*0 particle:
# Temperature: 80 MeV
# 0.00010578826479353437
#
# Temperature: 100 MeV
# 0.0012011242174534672
#
# Temperature: 120 MeV
# 0.006340600600916941
#
# Temperature: 140 MeV
# 0.02153866262029692
#
# Temperature: 160 MeV
# 0.05542669857585194
#
# Temperature: 180 MeV
# 0.11834746311637749
#
# Temperature: 200 MeV
# 0.22148626658246087
#
# K'-* particle:
# Temperature: 80 MeV
# 0.00010615203796297027
#
# Temperature: 100 MeV
# 0.0012042664113362982
#
# Temperature: 120 MeV
# 0.0063537672353602415
#
# Temperature: 140 MeV
# 0.021575241507157464
#
# Temperature: 160 MeV
# 0.055505422702836385
#
# Temperature: 180 MeV
# 0.11849052668786686
#
# Temperature: 200 MeV
# 0.22171739409002794

# %% [markdown]
# FOR W0

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) - z)
    entropy_density = (-(g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [782.65]  # Mass value for W0 particle in MeV/c^2
mu = 0
g = 3
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)




import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "W0"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-26-de3801bbc633>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-26-de3801bbc633>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-26-de3801bbc633>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
# Particle density results (fm^(-3)):
# [[2.524375841685121e-05, 0.00026055667468660883, 0.0013166069375934535, 0.004390596104440139, 0.011240129027882389, 0.024050173122209185, 0.04528643654883241]]
#
# Partial pressure results (fm^(-3)):
# [[0.0020194822507896004, 0.02605401911848336, 0.1579566889396904, 0.6143327477330481, 1.7963907460854058, 4.320744355117509, 9.030878428814857]]
#
# Energy density results (fm^(-3)):
# [[0.023136193094391976, 0.24851223592014177, 1.3064777754919366, 4.531007039185682, 12.056931063636888, 26.798032237698774, 52.379934391997026]]
#
# Entropy density results (fm^(-3)):
# [[0.00031444594181476973, 0.002745662550386251, 0.012203620536930228, 0.0367524270494195, 0.08658326131076434, 0.17288209218231265, 0.3070540641040594]]

# %% [markdown]
#  for P

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = (g / (2 * np.pi ** 2)) * y
    return entropy_density

mass_values_mev = [938.272]  # Mass value for proton particle in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)


import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

mass_values_mev = [938.272]  # Mass values for proton particles in MeV/c^2
particle_names = ["proton"]
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV
particle_name = "Proton"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-28-2cc1868dbda9>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-28-2cc1868dbda9>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-28-2cc1868dbda9>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# Particle density results (fm^(-3)):
# [[3.067525404569269e-06, 4.641392412974038e-05, 0.0003019877005536102, 0.0012038123381271938, 0.00351575050918449, 0.00831671719554197, 0.016934871175026563]]
#
# Partial pressure results (fm^(-3)):
# [[0.00024540235687446654, 0.004641455377211803, 0.036240833095739784, 0.16856600159754903, 0.5627650039260581, 1.498239444184464, 3.391586865248549]]
#
# Energy density results (fm^(-3)):
# [[0.003282336042140038, 0.05134616345196041, 0.34537433000522966, 1.423124639069364, 4.2953849296575966, 10.498629774454802, 22.082082806517047]]
#
# Entropy density results (fm^(-3)):
# [[4.4096729989532234e-05, 0.000559876188291722, 0.003180126359174745, 0.011369218861906524, 0.030363437084897842, 0.0666492734368848, 0.127368348358828]]

# %% [markdown]
# For neutron

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = (g / (2 * np.pi ** 2)) * y
    return entropy_density

mass_values_mev = [939.565]  # Mass value for neutron particle in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)





import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "Neutron"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-2-3426ee661174>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-2-3426ee661174>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-2-3426ee661174>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# Particle density results (fm^(-3)):
# [[3.023974940302528e-06, 4.590104602263178e-05, 0.0002992822712822561, 0.0011948181819369447, 0.0034933857508578883, 0.008270955670608123, 0.016853262911387577]]
#
# Partial pressure results (fm^(-3)):
# [[0.00024191830971976566, 0.004590166077956584, 0.035916136684773954, 0.16730628913828505, 0.5591831691287468, 1.489987086365492, 3.375214421704327]]
#
# Energy density results (fm^(-3)):
# [[0.0032396009826662162, 0.050837112386239634, 0.3426579569254376, 1.4139884091255803, 4.272398527750049, 10.45103544335124, 21.99618426080456]]
#
# Entropy density results (fm^(-3)):
# [[4.3518991154824765e-05, 0.0005542727846419623, 0.0031547841134184295, 0.011294962130456183, 0.03019738560549247, 0.06633901405398183, 0.12685699341264364]]

# %% [markdown]
# for lambda 0

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

mass_values_mev = [1115.683]  # Mass value for lambda particle in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)):")
print(results_particle_density)
print("\nPartial pressure results (fm^(-3)):")
print(results_partial_pressure)
print("\nEnergy density results (fm^(-3)):")
print(results_energy_density)
print("\nEntropy density results (fm^(-3)):")
print(results_entropy_density)




import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

particle_name = "Lambda0"
plt.plot(tmp_values_mev, results_particle_density[0], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-16-098f098212ea>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-16-098f098212ea>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-16-098f098212ea>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# Particle density results (fm^(-3)):
# [[4.22945642855178e-07, 9.918875326101077e-06, 8.630309632520804e-05, 0.0004229186339615865, 0.0014407295971465507, 0.0038391090527488433, 0.00859405345280441]]
#
# Partial pressure results (fm^(-3)):
# [[3.3835656257577046e-05, 0.0009918898463648293, 0.010356524452560153, 0.059211861284692434, 0.2305505491645857, 0.6912565889169001, 1.7198000073818231]]
#
# Energy density results (fm^(-3)):
# [[0.0005268636819064226, 0.012706720354648213, 0.11370037615563462, 0.5729788680614595, 2.00711349948376, 5.498862992404035, 12.653947320128129]]
#
# Entropy density results (fm^(-3)):
# [[7.008741728346998e-06, 0.00013698610201013042, 0.00103380750506829, 0.004515648066758228, 0.013985400304052159, 0.034389553229560756, 0.07186873663767512]]

# %% [markdown]
# For sigma+,Sigma 0, Sigma -

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

particle_names = ["
# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 +mass** 2)) / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

particle_names = ["Xi0*", "Xi-*"]
mass_values_mev = [1531.8, 1535]  # Mass values for Xi0* and Xi-* particles in MeV/c^2
mu = 0
g_values = [2, 2]  # Spin degeneracy factor (g) for Xi0* and Xi-* particles
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for i in range(len(mass_values_mev)):
    mass = mass_values_mev[i]
    g = g_values[i]
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)
    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

print("Particle density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_particle_density[i])

print("\nPartial pressure results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_partial_pressure[i])

print("\nEnergy density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_energy_density[i])

print("\nEntropy density results (fm^(-3)): ")
for i, particle_name in enumerate(particle_names):
    print(particle_name + ":")
    print(results_entropy_density[i])



import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

for i, particle_name in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{fm}^{-3}$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-11-d4d225165b15>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-11-d4d225165b15>:47: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
# <ipython-input-11-d4d225165b15>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 +mass** 2)) / (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) + 1)
# <ipython-input-11-d4d225165b15>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass** 2) - mu) / tmp) + 1))
# Particle density results (fm^(-3)):
# Xi0*:
# [3.6215516592512507e-09, 2.384622409088822e-07, 4.119517810618771e-06, 3.288572903669985e-05, 0.0001612932718835104, 0.0005699536949154754, 0.0015974857418015454]
# Xi-*:
# [3.4897812282967096e-09, 2.3162092630881239e-07, 4.022551491781466e-06, 3.223283484429434e-05, 0.00015853678154537987, 0.0005614369598360133, 0.0015763538792235047]
#
# Partial pressure results (fm^(-3)):
# Xi0*:
# [2.8972401984657676e-07, 2.384622493272692e-05, 0.0004943423708094326, 0.004604015368191606, 0.025807213209966148, 0.10259496723356502, 0.31952098673445556]
# Xi-*:
# [2.7918241417490623e-07, 2.3162093352235084e-05, 0.00048270639947321775, 0.004512609625823768, 0.025366164216099517, 0.10106184887510636, 0.3152939304364504]
#
# Energy density results (fm^(-3)):
# Xi0*:
# [6.0090141269165915e-06, 0.00040378157673108696, 0.007118982825883832, 0.05800124245973204, 0.29033980017075217, 1.047086969422117, 2.995138843944586]
# Xi-*:
# [5.801491668444418e-06, 0.0003929333679550341, 0.0069641601147037505, 0.056951521522258755, 0.28587681820816224, 1.0332002910273173, 2.9604381880788186]
#
# Entropy density results (fm^(-3)):
# Xi0*:
# [7.873422743978733e-08, 4.276278016064557e-06, 6.344437663911055e-05, 0.0004471804130565974, 0.001975918833629489, 0.00638712187032515, 0.016573299153395206]
# Xi-*:
# [7.60084249365864e-08, 4.160954613626263e-06, 6.205722095147475e-05, 0.0004390295082005895, 0.0019452686401516366, 0.006301456332837847, 0.016378660592576342]

# %% [markdown]
# For omega-

# %%
from scipy.integrate import quad
import numpy as np

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

particle_name = "Omega-"
mass_value_mev = 1672.45  # Mass value for Omega- particle in MeV/c^2
mu = 0
g = 4  # Spin degeneracy factor (g) for Omega- particle
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for tmp in tmp_values_mev:
    result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass_value_mev, mu, tmp))[0] * conversion_factor
    result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass_value_mev, mu, tmp))[0] * conversion_factor
    result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass_value_mev, mu, tmp))[0] * conversion_factor
    result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass_value_mev, mu, tmp))[0] * conversion_factor
    results_particle_density.append(result_particle_density)
    results_partial_pressure.append(result_partial_pressure)
    results_energy_density.append(result_energy_density)
    results_entropy_density.append(result_entropy_density)

print("Particle density results (MeV^3): ")
print(particle_name + ":")
print(results_particle_density)

print("\nPartial pressure results (MeV^3): ")
print(particle_name + ":")
print(results_partial_pressure)

print("\nEnergy density results (MeV^4): ")
print(particle_name + ":")
print(results_energy_density)

print("\nEntropy density results (MeV^3): ")
print(particle_name + ":")
print(results_entropy_density)




import matplotlib.pyplot as plt

# Plot particle density vs. temperature
plt.figure(figsize=(8, 6))

tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV
results_particle_density = [1.4132026063823186e-09, 1.3201995145762627e-07, 2.878018709579504e-06, 2.7115328840750583e-05, 0.00015053091347741912, 0.000585537596953139, 0.0017717392566932795]  # Particle density values for Omega-

plt.plot(tmp_values_mev, results_particle_density, label="Omega-")

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density ($\mathrm{MeV}^3$)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-17-2241a09ee44b>:5: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-17-2241a09ee44b>:40: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass_value_mev, mu, tmp))[0] * conversion_factor
# <ipython-input-17-2241a09ee44b>:15: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-17-2241a09ee44b>:20: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# Particle density results (MeV^3):
# Omega-:
# [1.4132026063823186e-09, 1.3201995145762627e-07, 2.878018709579504e-06, 2.7115328840750583e-05, 0.00015053091347741912, 0.000585537596953139, 0.0017717392566932795]
#
# Partial pressure results (MeV^3):
# Omega-:
# [1.1305620375969202e-07, 1.3201994903314826e-05, 0.0003453622945903952, 0.0037961500809753556, 0.024085059201339337, 0.10539833267862607, 0.35436105115129135]
#
# Energy density results (MeV^4):
# Omega-:
# [2.542763557247913e-06, 0.00024199450262427194, 0.005374658268530905, 0.05159172686254831, 0.2918140154309111, 1.1565103098663752, 3.5653367075485014]
#
# Entropy density results (MeV^3):
# Omega-:
# [3.319774702185388e-08, 2.5519649717359323e-06, 4.766683802601084e-05, 0.00039562769241655883, 0.001974369216451566, 0.007010603569696578, 0.01959848879349896]

# %% [markdown]
# Baryon resonance

# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return partial_pressure

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density

particle_names = ["Delta++", "Delta+", "Delta0", "Delta-", "Sigma+*", "Sigma0*", "Sigma-*", "Xi0*", "Xi-*", "Omega-"]
mass_values_mev = [1232, 1232, 1232, 1232, 1385, 1385, 1385, 1531.8, 1535, 1672.45]  # Mass values for particles in MeV/c^2
mu = 0
g_values = [4, 4, 4, 4, 2, 2, 2, 2, 2, 4]  # Statistical degeneracy values for particles
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []
conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for i, mass in enumerate(mass_values_mev):
    particle_density_results = []
    partial_pressure_results = []
    energy_density_results = []
    entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor

        particle_density_results.append(result_particle_density)
        partial_pressure_results.append(result_partial_pressure)
        energy_density_results.append(result_energy_density)
        entropy_density_results.append(result_entropy_density)

    results_particle_density.append(particle_density_results)
    results_partial_pressure.append(partial_pressure_results)
    results_energy_density.append(energy_density_results)
    results_entropy_density.append(entropy_density_results)

for i, name in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=name)
plt.xlabel("Temperature (MeV)")
plt.ylabel("Particle Density (fm^-3)")

plt.legend()
plt.show()
# Out:
# <ipython-input-22-dc775a92c0da>:6: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-22-dc775a92c0da>:16: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-22-dc775a92c0da>:21: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
# <ipython-input-22-dc775a92c0da>:45: IntegrationWarning: The maximum number of subdivisions (50) has been achieved.
#   If increasing the limit yields no improvement it is advised to analyze
#   the integrand in order to determine the difficulties.  If the position of a
#   local difficulty can be determined (singularity, discontinuity) one will
#   probably gain from splitting up the interval and calling the integrator
#   on the subranges.  Perhaps a special-purpose integrator should be used.
#   result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor

# %% [markdown]
# Baryon

# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

mass_values_mev = [938.272, 939.565, 1115.683, 1189.37, 1192.642, 1197.449, 1314.86, 1321.71]  # Mass values for particles in MeV/c^2
particle_names = ['Proton', 'Neutron', 'Lambda0', 'Sigma+', 'Sigma0', 'Sigma-', 'Xi0', 'Xi-',]
mu = 0
g_values = [2, 2, 2, 2, 2, 2, 2, 2]
tmp_values_mev = [80, 90, 100, 110, 120, 130, 140, 150,160, 170, 180, 190, 200]  # Example temperature values in MeV

results_particle_density = [[] for _ in range(len(mass_values_mev))]

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for i, mass in enumerate(mass_values_mev):
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor
        results_particle_density[i].append(result_particle_density)

plt.figure(figsize=(8, 5))

for i, particle_name in enumerate(particle_names):
    plt.plot(tmp_values_mev, results_particle_density[i], label=particle_name)

plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density (fm^-3)')
plt.title('Particle Density vs. Temperature')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# <ipython-input-37-2ca9e3adab77>:6: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)

# %% [markdown]
# test

# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

mass_values_mev = [938.272, 939.565, 1115.683, 1189.37, 1192.642, 1197.449, 1314.86, 1321.71, 1672.45]  # Mass values for particles in MeV/c^2
particle_names = ['Proton', 'Neutron', 'Lambda0', 'Sigma+', 'Sigma0', 'Sigma-', 'Xi0', 'Xi-', 'Omega-']
mu = 0
g_values = [2, 2, 2, 2, 2, 2, 2, 2, 2]
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # Example temperature values in MeV

results_particle_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for tmp in tmp_values_mev:
    sum_particle_density = 0.0
    for i, mass in enumerate(mass_values_mev):
        result_particle_density = quad(particle_density, 0, np.inf, args=(g_values[i], mass, mu, tmp))[0] * conversion_factor
        sum_particle_density += result_particle_density
    results_particle_density.append(sum_particle_density)

plt.figure(figsize=(10, 8))
plt.plot(tmp_values_mev, results_particle_density)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density (fm^-3)')
plt.title('Sum of Particle Densities vs. Temperature')
plt.grid(True)
plt.show()

# %% [markdown]
# XYZ

# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = ((g * tmp) / (2 * np.pi ** 2)) * y
    return 3 * partial_pressure / (tmp ** 4)

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density / (tmp ** 4)

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))
    y = x ** 2 * (np.log((1 + np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density / (tmp ** 3)

mass_values_mev = [938, 939.6, 1115.7, 1189.37, 1192.642, 1197.45, 1314.86, 1321.71]  # mass values for p, n, lambda0, sigma+, sigma0, sigma-, xi0, xi- particles in MeV/c^2
mu = 0
g = 2
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, 0, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)

    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

mass_labels = ['p', 'n', 'lambda0', 'sigma+', 'sigma0', 'sigma-', 'xi0', 'xi-']
tmp_labels = [str(tmp) for tmp in tmp_values_mev]

# Plotting particle density
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_particle_density[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density (fm^(-3))')
plt.title('Particle Density vs Temperature')
plt.legend()
plt.show()

# Plotting partial pressure
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_partial_pressure[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Partial Pressure (fm^(-4))')
plt.title('Partial Pressure vs Temperature')
plt.legend()
plt.show()

# Plotting energy density
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_energy_density[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Energy Density (fm^(-4))')
plt.title('Energy Density vs Temperature')
plt.legend()
plt.show()

# Plotting entropy density
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_entropy_density[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Entropy Density (fm^(-3))')
plt.title('Entropy Density vs Temperature')
plt.legend()
plt.show()
# Out:
# <ipython-input-1-5a0296041ceb>:6: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-1-5a0296041ceb>:16: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1)
# <ipython-input-1-5a0296041ceb>:21: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) + 1))

# %%
from scipy.integrate import quad
import numpy as np
import matplotlib.pyplot as plt

def particle_density(x, g, mass, mu, tmp):
    y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    particle_density = (g / (2.0 * np.pi ** 2)) * y
    return particle_density

def partial_pressure(x, g, mass, mu, tmp):
    y = x ** 2 * np.log(1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))
    partial_pressure = (-(g * tmp) / (2 * np.pi ** 2)) * y
    return 3 * partial_pressure / (tmp ** 4)

def energy_density(x, g, mass, mu, tmp):
    y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
    energy_density = (g / (2.0 * np.pi ** 2)) * y
    return energy_density / (tmp ** 4)

def entropy_density(x, g, mass, mu, tmp):
    z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
    y = x ** 2 * (np.log((1 - np.exp(-(np.sqrt(x ** 2 + mass ** 2) - mu) / tmp))) + z)
    entropy_density = ((g / (2 * np.pi ** 2))) * y
    return entropy_density / (tmp ** 3)

mass_values_mev = [139.57, 139.57, 134.98, 493.68, 493.68, 497.61, 497.61, 547.86]  # mass values for π+, π-, π0, K+, K-, K0, K~0, η0 in MeV/c^2
mu = 0
g = 1
tmp_values_mev = [80, 100, 120, 140, 160, 180, 200]  # temperature values in MeV

results_particle_density = []
results_partial_pressure = []
results_energy_density = []
results_entropy_density = []

conversion_factor = (1.25e-7)  # Conversion factor from MeV^3 to fm^(-3)

for mass in mass_values_mev:
    mass_particle_density_results = []
    mass_partial_pressure_results = []
    mass_energy_density_results = []
    mass_entropy_density_results = []
    for tmp in tmp_values_mev:
        result_particle_density = quad(particle_density, mass / tmp, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_partial_pressure = quad(partial_pressure, mass / tmp, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_energy_density = quad(energy_density, mass / tmp, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor
        result_entropy_density = quad(entropy_density, mass / tmp, np.inf, args=(g, mass, mu, tmp))[0] * conversion_factor

        mass_particle_density_results.append(result_particle_density)
        mass_partial_pressure_results.append(result_partial_pressure)
        mass_energy_density_results.append(result_energy_density)
        mass_entropy_density_results.append(result_entropy_density)

    results_particle_density.append(mass_particle_density_results)
    results_partial_pressure.append(mass_partial_pressure_results)
    results_energy_density.append(mass_energy_density_results)
    results_entropy_density.append(mass_entropy_density_results)

mass_labels = ['pi+', 'pi-', 'pi0', 'K+', 'K-', 'K0', 'K~0', 'eta0']
tmp_labels = [str(tmp) for tmp in tmp_values_mev]

# Plotting particle density
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_particle_density[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Particle Density (fm^(-3))')
plt.title('Particle Density vs Temperature')
plt.legend()
plt.show()

# Plotting partial pressure
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_partial_pressure[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Partial Pressure (fm^(-4))')
plt.title('Partial Pressure vs Temperature')
plt.legend()
plt.show()

# Plotting energy density
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_energy_density[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Energy Density (fm^(-4))')
plt.title('Energy Density vs Temperature')
plt.legend()
plt.show()

# Plotting entropy density
plt.figure(figsize=(10, 6))
for i, mass_label in enumerate(mass_labels):
    plt.plot(tmp_values_mev, results_entropy_density[i], label=mass_label)
plt.xlabel('Temperature (MeV)')
plt.ylabel('Entropy Density (fm^(-3))')
plt.title('Entropy Density vs Temperature')
plt.legend()
plt.show()
# Out:
# <ipython-input-2-dc26b249391d>:6: RuntimeWarning: overflow encountered in exp
#   y = x ** 2 / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-2-dc26b249391d>:16: RuntimeWarning: overflow encountered in exp
#   y = (x ** 2 * np.sqrt(x ** 2 + mass ** 2)) / (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1)
# <ipython-input-2-dc26b249391d>:21: RuntimeWarning: overflow encountered in exp
#   z = (np.sqrt(x ** 2 + mass ** 2) - mu) / (tmp * (np.exp((np.sqrt(x ** 2 + mass ** 2) - mu) / tmp) - 1))
